# %% [markdown]
# ## Decision Tree Regression

# %%
import pandas as pd

# %%
data = pd.read_csv("Cotton.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166585 entries, 0 to 166584
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Region                  166585 non-null  object
#  1   Soil_Type               166585 non-null  object
#  2   Crop                    166585 non-null  object
#  3   Rainfall_mm             166585 non-null  float64
#  4   Temperature_Celsius     166585 non-null  float64
#  5   Fertilizer_Used         166585 non-null  bool
#  6   Irrigation_Used         166585 non-null  bool
#  7   Weather_Condition       166585 non-null  object
#  8   Days_to_Harvest         166585 non-null  int64
#  9   Yield_tons_per_hectare  166585 non-null  float64
# dtypes: bool(2), float64(3), int64(1), object(4)
# memory usage: 10.5+ MB

# %%
data.isnull()
# Out:
#         Region  Soil_Type   Crop  Rainfall_mm  Temperature_Celsius  \
# 0        False      False  False        False                False
# 1        False      False  False        False                False
# 2        False      False  False        False                False
# 3        False      False  False        False                False
# 4        False      False  False        False                False
# ...        ...        ...    ...          ...                  ...
# 166580   False      False  False        False                False
# 166581   False      False  False        False                False
# 166582   False      False  False        False                False
# 166583   False      False  False        False                False
# 166584   False      False  False        False                False
#
#         Fertilizer_Used  Irrigation_Used  Weather_Condition  Days_to_Harvest  \
# 0                 False            False              False            False
# 1                 False            False              False            False
# 2                 False            False              False            False
# 3                 False            False              False            False
# 4                 False            False              False            False
# ...                 ...              ...                ...              ...
# 166580            False            False              False            False
# 166581            False            False              False            False
# 166582            False            False              False            False
# 166583            False            False              False            False
# 166584            False            False              False            False
#
#         Yield_tons_per_hectare
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 166580                   False
# 166581                   False
# 166582                   False
# 166583                   False
# 166584                   False
#
# [166585 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# Region                    0
# Soil_Type                 0
# Crop                      0
# Rainfall_mm               0
# Temperature_Celsius       0
# Fertilizer_Used           0
# Irrigation_Used           0
# Weather_Condition         0
# Days_to_Harvest           0
# Yield_tons_per_hectare    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
df = pd.DataFrame(data)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_features = ["Region", "Soil_Type", "Fertilizer_Used", "Irrigation_Used", "Weather_Condition"]

# %%
label_encoders = {}

# %%
for feature in categorical_features:
    le = LabelEncoder()
    data[feature] = le.fit_transform(df[feature])
    label_encoders[feature] = le

# %%
X = data.drop(columns=["Yield_tons_per_hectare","Crop"])
y = data["Yield_tons_per_hectare"]

# %%
X
# Out:
#         Region  Soil_Type  Rainfall_mm  Temperature_Celsius  Fertilizer_Used  \
# 0            3          4   897.077239            27.676966                0
# 1            0          4   145.300681            19.755535                1
# 2            2          3   607.150252            15.562163                1
# 3            1          1   416.898632            23.190810                1
# 4            0          1   990.267439            24.072052                0
# ...        ...        ...          ...                  ...              ...
# 166580       1          3   217.387025            27.306320                0
# 166581       2          2   528.002127            37.384126                0
# 166582       1          0   959.604272            32.334733                0
# 166583       2          2   315.605610            30.119779                1
# 166584       1          3   867.362046            24.370042                1
#
#         Irrigation_Used  Weather_Condition  Days_to_Harvest
# 0                     1                  0              122
# 1                     1                  0              141
# 2                     1                  2              136
# 3                     1                  2               95
# 4                     1                  2              110
# ...                 ...                ...              ...
# 166580                0                  0              137
# 166581                1                  1               62
# 166582                0                  0              109
# 166583                1                  0              118
# 166584                0                  0              108
#
# [166585 rows x 8 columns]

# %%
y
# Out:
# 0         6.555816
# 1         4.367612
# 2         6.525186
# 3         4.858924
# 4         6.187396
#             ...
# 166580    1.001849
# 166581    3.571633
# 166582    5.097432
# 166583    4.802915
# 166584    5.763182
# Name: Yield_tons_per_hectare, Length: 166585, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
MSE = mean_squared_error(y_test, predictions)

# %%
print(f"Mean Squared Error: {MSE}")
# Out:
# Mean Squared Error: 0.5328024149623037

# %%
MAE = mean_absolute_error(y_test, predictions)

# %%
print(f"Mean Absolute Error: {MAE}")
# Out:
# Mean Absolute Error: 0.5822081477258271

# %%
RSquared = r2_score(y_test, predictions)

# %%
print(f"RSquared Score: {RSquared}")
# Out:
# RSquared Score: 0.815454997670698

# %% [markdown]
# # Hyperparameter Tuning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "max_depth": [3, 5, 10, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ['auto', 'sqrt', 'log2', None]
}

# %%
grid_search = GridSearchCV(model, param_grid, cv=5, scoring="neg_mean_squared_error")

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\suren\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 180 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\suren\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\suren\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\suren\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\suren\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\suren\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan -1.92134097 -1.64179436 -1.89557065
#  -1.68795596 -1.51951542 -1.60696592 -2.1384422  -1.77792464 -1.95222079
#  -1.62587786 -0.94849293 -1.19023666 -1.08066965 -1.15849517 -1.20801748
#  -1.50754459 -1.44373919 -1.03146724 -0.69212457 -0.69212457 -0.69212457
#  -0.69212457 -0.69212457 -0.69212457 -0.69212457 -0.69212457 -0.69212457
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan -1.05098593 -1.2292345  -1.37939074
#  -0.83628779 -1.00463393 -1.06038987 -1.1016623  -1.44364908 -1.01648276
#  -0.70435717 -0.84240324 -0.83762605 -0.78272059 -0.91342408 -0.76280066
#  -0.96415466 -0.8449973  -0.8124338  -0.29900682 -0.29900682 -0.29900682
#  -0.29900682 -0.29900682 -0.29900682 -0.29900682 -0.29900682 -0.29900682
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan -0.52113588 -0.55298538 -0.47233499
#  -0.50144377 -0.51027282 -0.52162316 -0.62275169 -0.64314971 -0.54860416
#  -0.33070158 -0.3263043  -0.33688393 -0.37359064 -0.40810505 -0.31565181
#  -0.41562257 -0.33044368 -0.33218424 -0.26634819 -0.26628917 -0.26620646
#  -0.26601165 -0.26594562 -0.26590165 -0.26565664 -0.26565664 -0.26563713
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan -0.58934166 -0.51702224 -0.45476087
#  -0.49028539 -0.49928969 -0.44304976 -0.43229331 -0.43237171 -0.42034589
#  -0.54282857 -0.47981428 -0.41021922 -0.45086147 -0.44249893 -0.39975999
#  -0.37734538 -0.37825622 -0.37377025 -0.53118633 -0.49577515 -0.4331143
#  -0.47853764 -0.46703442 -0.41418414 -0.40163645 -0.40160052 -0.39003434]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [3, 5, 10, None],
#                          'max_features': ['auto', 'sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10}

# %%
best_model = grid_search.best_estimator_

# %%
best_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=4, min_samples_split=10)

# %%
predictions = best_model.predict(X_test)

# %%
MSE = mean_squared_error(y_test, predictions)

# %%
print(f"Mean Squared Error: {MSE}")
# Out:
# Mean Squared Error: 0.2635642450846912

# %%
MAE = mean_absolute_error(y_test, predictions)

# %%
print(f"Mean Absolute Error: {MAE}")
# Out:
# Mean Absolute Error: 0.4084062272014661

# %%
RSquared = r2_score(y_test, predictions)

# %%
print(f"RSquared Score: {RSquared}")
# Out:
# RSquared Score: 0.9075794758028285

# %% [markdown]
# # Hyperparameter Tuning with Optuna

# %%
import optuna

# %%
def objective(trial):
    max_depth = trial.suggest_int('max_depth', 2, 20)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    #Define and Train the Model
    model = DecisionTreeRegressor(
        max_depth = max_depth,
        min_samples_split = min_samples_split,
        min_samples_leaf = min_samples_leaf,
        max_features = max_features,
        random_state = 42
    )
    model.fit(X_train, y_train)
    #Predict and Evaluate using Mean Squared Error
    predictions = model.predict(X_test)
    MSE = mean_squared_error(y_test, predictions)
    return MSE

# %%
#Create an Optuna Study and Optimize it
study = optuna.create_study(direction = 'minimize')
study.optimize(objective, n_trials = 100)
# Out:
# [I 2025-02-28 10:00:06,812] A new study created in memory with name: no-name-e520e255-6185-4553-84f8-e7ccd8dbfe6d
# [I 2025-02-28 10:00:07,014] Trial 0 finished with value: 0.3311063549867079 and parameters: {'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:07,197] Trial 1 finished with value: 0.4085313820182957 and parameters: {'max_depth': 19, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:07,362] Trial 2 finished with value: 0.40743456512626286 and parameters: {'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:08,065] Trial 3 finished with value: 0.35816313205484956 and parameters: {'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:08,328] Trial 4 finished with value: 0.34168700303223526 and parameters: {'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:08,588] Trial 5 finished with value: 0.34725922491817074 and parameters: {'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:08,648] Trial 6 finished with value: 1.5655961280280204 and parameters: {'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:08,788] Trial 7 finished with value: 0.5450236121503106 and parameters: {'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.3311063549867079.
# [I 2025-02-28 10:00:09,230] Trial 8 finished with value: 0.2578911968760671 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:09,631] Trial 9 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:09,768] Trial 10 finished with value: 1.0608291461131414 and parameters: {'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:10,110] Trial 11 finished with value: 0.27802425971133315 and parameters: {'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:10,478] Trial 12 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:11,063] Trial 13 finished with value: 0.29767587812956847 and parameters: {'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:11,446] Trial 14 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:12,013] Trial 15 finished with value: 0.29483184209493035 and parameters: {'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:12,431] Trial 16 finished with value: 0.2578911968760671 and parameters: {'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:12,913] Trial 17 finished with value: 0.26297941900446364 and parameters: {'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:13,514] Trial 18 finished with value: 0.3132846668617734 and parameters: {'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:13,586] Trial 19 finished with value: 1.5655961280280204 and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:14,009] Trial 20 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:14,430] Trial 21 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:14,922] Trial 22 finished with value: 0.2714283433261638 and parameters: {'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:15,305] Trial 23 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:15,571] Trial 24 finished with value: 0.2979621745436467 and parameters: {'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:16,063] Trial 25 finished with value: 0.2718229049110123 and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:16,639] Trial 26 finished with value: 0.3035910392372671 and parameters: {'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:17,055] Trial 27 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:17,217] Trial 28 finished with value: 0.5575205652013254 and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:17,428] Trial 29 finished with value: 0.3536703661737758 and parameters: {'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:17,580] Trial 30 finished with value: 0.3933069018505755 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:18,039] Trial 31 finished with value: 0.2632496825255032 and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 8 with value: 0.2578911968760671.
# [I 2025-02-28 10:00:18,447] Trial 32 finished with value: 0.25788837671296144 and parameters: {'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:18,850] Trial 33 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:19,154] Trial 34 finished with value: 0.27802425971133315 and parameters: {'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:19,659] Trial 35 finished with value: 0.2712376688183819 and parameters: {'max_depth': 11, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:19,865] Trial 36 finished with value: 0.4602329485900056 and parameters: {'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:19,982] Trial 37 finished with value: 0.9618336409688869 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:20,647] Trial 38 finished with value: 0.3625179049203589 and parameters: {'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:20,784] Trial 39 finished with value: 0.8027789879254902 and parameters: {'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:20,915] Trial 40 finished with value: 1.0608291461131414 and parameters: {'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:21,328] Trial 41 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:21,716] Trial 42 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:22,072] Trial 43 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:22,527] Trial 44 finished with value: 0.2632430673251978 and parameters: {'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:22,683] Trial 45 finished with value: 0.5441409696125775 and parameters: {'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:22,981] Trial 46 finished with value: 0.27802425971133315 and parameters: {'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:23,486] Trial 47 finished with value: 0.2711579256079428 and parameters: {'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:24,076] Trial 48 finished with value: 0.2934218707128669 and parameters: {'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:24,740] Trial 49 finished with value: 0.3246184716912302 and parameters: {'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:25,208] Trial 50 finished with value: 0.25789947609895486 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:25,625] Trial 51 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:26,151] Trial 52 finished with value: 0.26378342095847124 and parameters: {'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:26,716] Trial 53 finished with value: 0.28422022574204137 and parameters: {'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:27,134] Trial 54 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:27,606] Trial 55 finished with value: 0.25797073725865066 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:27,732] Trial 56 finished with value: 0.5904760216402248 and parameters: {'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:28,066] Trial 57 finished with value: 0.27802425971133315 and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:28,422] Trial 58 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:28,621] Trial 59 finished with value: 0.4250622135442544 and parameters: {'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:29,056] Trial 60 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:29,507] Trial 61 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:29,975] Trial 62 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:30,369] Trial 63 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:30,832] Trial 64 finished with value: 0.2632496825255032 and parameters: {'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:31,267] Trial 65 finished with value: 0.25788837671296144 and parameters: {'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:31,764] Trial 66 finished with value: 0.271908811599958 and parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:32,303] Trial 67 finished with value: 0.2831074492595666 and parameters: {'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:32,433] Trial 68 finished with value: 0.6880021467880241 and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:32,801] Trial 69 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:32,992] Trial 70 finished with value: 0.35288614645922894 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:33,412] Trial 71 finished with value: 0.2579224278960702 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:33,800] Trial 72 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 32 with value: 0.25788837671296144.
# [I 2025-02-28 10:00:34,224] Trial 73 finished with value: 0.2578706773084074 and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:34,690] Trial 74 finished with value: 0.26305531213031663 and parameters: {'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:35,078] Trial 75 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:35,429] Trial 76 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:35,928] Trial 77 finished with value: 0.2711579256079428 and parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:36,200] Trial 78 finished with value: 0.2979621745436467 and parameters: {'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:36,631] Trial 79 finished with value: 0.2578706773084074 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:37,027] Trial 80 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:37,451] Trial 81 finished with value: 0.2578911968760671 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:37,915] Trial 82 finished with value: 0.26297941900446364 and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:38,348] Trial 83 finished with value: 0.25788338148800005 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:38,798] Trial 84 finished with value: 0.25788338148800005 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:39,241] Trial 85 finished with value: 0.25788338148800005 and parameters: {'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:39,641] Trial 86 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:39,780] Trial 87 finished with value: 0.7062393065849634 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:40,325] Trial 88 finished with value: 0.2709234619760986 and parameters: {'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:40,490] Trial 89 finished with value: 0.453514702621598 and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:40,813] Trial 90 finished with value: 0.27802425971133315 and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:41,296] Trial 91 finished with value: 0.2578911968760671 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:41,785] Trial 92 finished with value: 0.26278182411468387 and parameters: {'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:42,190] Trial 93 finished with value: 0.2642014042303736 and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:42,692] Trial 94 finished with value: 0.2578911968760671 and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:43,195] Trial 95 finished with value: 0.25788338148800005 and parameters: {'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:43,601] Trial 96 finished with value: 0.2592104091533075 and parameters: {'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:44,068] Trial 97 finished with value: 0.25788338148800005 and parameters: {'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:44,691] Trial 98 finished with value: 0.3152490644064491 and parameters: {'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.
# [I 2025-02-28 10:00:45,228] Trial 99 finished with value: 0.2806184580918125 and parameters: {'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 73 with value: 0.2578706773084074.

# %%
study.best_params
# Out:
# {'max_depth': 9,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_features': None}

# %%
study.best_value
# Out:
# 0.2578706773084074

# %%
best_params = study.best_params

# %%
best_model = DecisionTreeRegressor(**best_params)

# %%
best_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=9, min_samples_leaf=8)

# %%
predictions = best_model.predict(X_test)

# %%
MSE = mean_squared_error(y_test, predictions)

# %%
print(f"Mean Squared Error: {MSE}")
# Out:
# Mean Squared Error: 0.2578706773084074

# %%
MAE = mean_absolute_error(y_test, predictions)

# %%
print(f"Mean Absolute Error: {MAE}")
# Out:
# Mean Absolute Error: 0.4042926718067476

# %%
RSquared = r2_score(y_test, predictions)

# %%
print(f"RSquared Score: {RSquared}")
# Out:
# RSquared Score: 0.9095759625351892
